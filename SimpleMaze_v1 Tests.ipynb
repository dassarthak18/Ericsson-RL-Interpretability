# %%
import gym
from src import algo
# Out:
# 2022-03-30 16:10:00.892992: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:00.893042: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Creating the environment
from env.SimpleMaze_v1 import SimpleMaze
env = SimpleMaze(4,4,True)
# Out:
# Map:
# 0 * * 0
# * 0 * X
# 0 0 0 0
# G 0 0 0

# %% [markdown]
# ## DQN 1000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,1000)
# Out:
# 2022-03-22 20:10:41.489919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 20:10:41.490732: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.490925: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491109: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491287: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491464: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491641: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491816: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.491995: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-22 20:10:41.492024: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-22 20:10:41.492732: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training for 1000 steps ...
# Interval 1 (0 steps performed)
#    55/10000 [..............................] - ETA: 18s - reward: -0.7818
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   999/10000 [=>............................] - ETA: 1:26 - reward: -1.4004done, took 9.732 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
from src.data import dataset
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 575.85it/s]

# %%
# Building DT from the dataset
from src.tree import build_tree
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
from src.tree import visualize_tree
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
from src.tree import test_tree
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 482.14it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 2000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,2000)
# Out:
# Training for 2000 steps ...
# Interval 1 (0 steps performed)
#    33/10000 [..............................] - ETA: 15s - reward: -0.3939
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#  2000/10000 [=====>........................] - ETA: 1:27 - reward: -1.4730done, took 21.883 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 537.62it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 474.92it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 5000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,5000)
# Out:
# 2022-03-30 16:10:28.613571: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-30 16:10:28.614820: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.615137: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.615411: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.615633: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.615845: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.616066: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.616288: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.616547: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-30 16:10:28.616591: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-30 16:10:28.617551: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training for 5000 steps ...
# Interval 1 (0 steps performed)
#    55/10000 [..............................] - ETA: 18s - reward: -0.8545
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#  4996/10000 [=============>................] - ETA: 52s - reward: -1.1167done, took 52.721 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 518.06it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 454.99it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 10000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,10000)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 104s 10ms/step - reward: -0.8794
# done, took 103.681 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 500.14it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 469.33it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 20000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,20000)
# Out:
# Training for 20000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 112s 11ms/step - reward: -1.0220
# 346 episodes - episode_reward: -29.540 [-556.000, 26.000] - loss: 7.121 - mse: 158.798 - mean_q: -12.946
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 113s 11ms/step - reward: -0.8585
# done, took 225.159 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 510.16it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 444.74it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 50000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,50000)
# Out:
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 116s 12ms/step - reward: -1.1067
# 318 episodes - episode_reward: -34.799 [-623.000, 26.000] - loss: 7.070 - mse: 183.516 - mean_q: -13.818
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 117s 12ms/step - reward: -0.7192
# 441 episodes - episode_reward: -16.313 [-379.000, 30.000] - loss: 7.487 - mse: 153.441 - mean_q: -12.946
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 118s 12ms/step - reward: -0.4926
# 539 episodes - episode_reward: -9.122 [-211.000, 30.000] - loss: 5.616 - mse: 38.028 - mean_q: -5.684
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -0.4414
# 547 episodes - episode_reward: -7.995 [-177.000, 27.000] - loss: 5.354 - mse: 13.205 - mean_q: -2.517
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 132s 13ms/step - reward: -0.4510
# done, took 606.718 seconds

# %%
model.save("SimpleMaze_v1_DQN_50000")
# Out:
# 2022-03-30 16:22:02.733847: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: SimpleMaze_v1_DQN_50000/assets

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 512.32it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 436.82it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 100000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,100000)
# Out:
# Training for 100000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 117s 12ms/step - reward: -0.8277
# 412 episodes - episode_reward: -20.090 [-290.000, 28.000] - loss: 5.767 - mse: 76.496 - mean_q: -8.516
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 120s 12ms/step - reward: -0.5072
# 526 episodes - episode_reward: -9.633 [-227.000, 27.000] - loss: 5.582 - mse: 21.217 - mean_q: -3.656
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 122s 12ms/step - reward: -0.5136
# 537 episodes - episode_reward: -9.581 [-189.000, 29.000] - loss: 5.631 - mse: 10.475 - mean_q: -1.982
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 126s 13ms/step - reward: -0.4621
# 534 episodes - episode_reward: -8.640 [-161.000, 29.000] - loss: 5.742 - mse: 7.811 - mean_q: -1.310
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -0.4281
# 547 episodes - episode_reward: -7.848 [-243.000, 29.000] - loss: 5.838 - mse: 7.180 - mean_q: -1.123
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 130s 13ms/step - reward: -0.5084
# 530 episodes - episode_reward: -9.349 [-203.000, 34.000] - loss: 6.053 - mse: 5.614 - mean_q: -0.566
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 130s 13ms/step - reward: -0.5971
# 512 episodes - episode_reward: -11.908 [-273.000, 31.000] - loss: 5.935 - mse: 6.621 - mean_q: -0.956
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 132s 13ms/step - reward: -0.5107
# 555 episodes - episode_reward: -9.178 [-179.000, 26.000] - loss: 5.881 - mse: 7.764 - mean_q: -1.351
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 130s 13ms/step - reward: -0.5435
# 513 episodes - episode_reward: -10.595 [-195.000, 27.000] - loss: 5.929 - mse: 7.046 - mean_q: -1.127
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 131s 13ms/step - reward: -0.5570
# done, took 1268.560 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 493.49it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 429.75it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%
