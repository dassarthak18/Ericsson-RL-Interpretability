# %%
import gym
from src import algo
# Out:
# 2022-03-30 15:51:16.599924: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 15:51:16.600005: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Creating the environment
from env.SimpleMaze_v0 import SimpleMaze
env = SimpleMaze(True)
# Out:
# Map:
# 0 0 0 0
# * X 0 *
# 0 G * 0
# 0 * 0 0

# %% [markdown]
# ## DQN 1000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,1000)
# Out:
# 2022-03-22 21:05:10.261888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 21:05:10.262579: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.262709: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.262819: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.262925: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.263027: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.263130: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.263229: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.263331: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-22 21:05:10.263348: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-22 21:05:10.264045: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training for 1000 steps ...
# Interval 1 (0 steps performed)
#    78/10000 [..............................] - ETA: 13s - reward: -1.4487
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   999/10000 [=>............................] - ETA: 1:35 - reward: -0.3534done, took 10.653 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
from src.data import dataset
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 572.14it/s]

# %%
# Building DT from the dataset
from src.tree import build_tree
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
from src.tree import visualize_tree
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
from src.tree import test_tree
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 389.76it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 2000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,2000)
# Out:
# Training for 2000 steps ...
# Interval 1 (0 steps performed)
#    38/10000 [..............................] - ETA: 13s - reward: -1.2895
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#  2000/10000 [=====>........................] - ETA: 1:25 - reward: -0.6480done, took 21.575 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 529.98it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 500.67it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 5000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,5000)
# Out:
# Training for 5000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 29:23 - reward: 9.0000
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#  4998/10000 [=============>................] - ETA: 53s - reward: -0.3832done, took 54.096 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 539.11it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 492.05it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 10000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,10000)
# Out:
# Training for 10000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 110s 11ms/step - reward: -0.4828
# done, took 109.852 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 545.08it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 503.65it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 20000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,20000)
# Out:
# Training for 20000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 113s 11ms/step - reward: -0.3957
# 628 episodes - episode_reward: -6.279 [-507.000, 29.000] - loss: 4.699 - mse: 6.990 - mean_q: 1.822
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 114s 11ms/step - reward: -0.4582
# done, took 226.774 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 500.30it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 488.46it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 50000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,50000)
# Out:
# 2022-03-30 15:52:19.200830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-30 15:52:19.201680: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.201818: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.201929: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202035: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202135: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202274: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202388: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202498: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-03-30 15:52:19.202516: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-03-30 15:52:19.202969: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Training for 50000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 111s 11ms/step - reward: -0.5090
# 547 episodes - episode_reward: -9.324 [-306.000, 22.000] - loss: 4.630 - mse: 4.016 - mean_q: 1.361
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 111s 11ms/step - reward: -0.4758
# 525 episodes - episode_reward: -8.994 [-215.000, 26.000] - loss: 4.825 - mse: 4.716 - mean_q: 1.135
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 116s 12ms/step - reward: -0.3404
# 559 episodes - episode_reward: -6.102 [-277.000, 28.000] - loss: 4.872 - mse: 4.587 - mean_q: 0.843
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 115s 12ms/step - reward: -0.3194
# 498 episodes - episode_reward: -6.432 [-163.000, 29.000] - loss: 5.023 - mse: 4.146 - mean_q: 1.112
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 119s 12ms/step - reward: -0.3787
# done, took 573.081 seconds

# %%
model.save("SimpleMaze_v0_DQN_50000")
# Out:
# 2022-03-30 16:03:09.218466: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: SimpleMaze_v0_DQN_50000/assets

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 497.33it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 453.53it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%

# %% [markdown]
# ## DQN 100000 timesteps

# %%
# Training an RL agent in the environment using given algorithm
model, agent, train_rewards = algo.dqn(env,100000)
# Out:
# Training for 100000 steps ...
# Interval 1 (0 steps performed)
# /usr/local/lib/python3.9/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 122s 12ms/step - reward: -0.2878
# 797 episodes - episode_reward: -3.509 [-246.000, 23.000] - loss: 4.941 - mse: 5.465 - mean_q: 0.811
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 120s 12ms/step - reward: -0.2982
# 533 episodes - episode_reward: -5.743 [-293.000, 26.000] - loss: 5.230 - mse: 4.374 - mean_q: 1.162
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 120s 12ms/step - reward: -0.4067
# 492 episodes - episode_reward: -8.295 [-217.000, 26.000] - loss: 5.294 - mse: 4.416 - mean_q: 0.933
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 123s 12ms/step - reward: -0.5795
# 394 episodes - episode_reward: -14.683 [-391.000, 27.000] - loss: 5.308 - mse: 4.099 - mean_q: 1.613
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 130s 13ms/step - reward: -0.0031
# 748 episodes - episode_reward: -0.039 [-188.000, 28.000] - loss: 5.292 - mse: 5.267 - mean_q: 0.267
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -0.3451
# 496 episodes - episode_reward: -6.972 [-282.000, 24.000] - loss: 5.304 - mse: 4.314 - mean_q: 0.845
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 129s 13ms/step - reward: -0.5051
# 443 episodes - episode_reward: -11.406 [-201.000, 24.000] - loss: 5.278 - mse: 4.222 - mean_q: 1.141
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 131s 13ms/step - reward: -0.3102
# 563 episodes - episode_reward: -5.506 [-253.000, 24.000] - loss: 5.338 - mse: 4.634 - mean_q: 0.636
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 130s 13ms/step - reward: -0.3525
# 507 episodes - episode_reward: -6.675 [-650.000, 28.000] - loss: 5.316 - mse: 4.663 - mean_q: 1.210
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 132s 13ms/step - reward: -0.2939
# done, took 1267.256 seconds

# %%
# Visualizing Training History
plt = algo.plot_training(train_rewards)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %%
# Generating dataset for ANN to DT conversion
# !rm "simple_maze_4_by_4_data.csv"
filename = "simple_maze_4_by_4_data.csv"
dataset(env,model,filename)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 448.74it/s]

# %%
# Building DT from the dataset
Tree = build_tree(env,filename)

# %%
# Visualizing the DT
graph = visualize_tree(env,Tree)
graph

# %%
# Testing DT against ANN for accuracy
test_tree(env,model,Tree)
# Out:
# 100%|████████████████████████████████████████| 128/128 [00:00<00:00, 451.47it/s]
# Instances checked: 128
# Predictions matched: 128
# Accuracy: 100.0%
